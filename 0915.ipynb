# %%
import pandas as pd

# !pip install pycham
# Out:
# ...
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  1.2/1.2 MB 19.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#      ----------------- ---------------------- 3.0/6.8 MB 63.0 MB/s eta 0:00:01
#      ---------------------------------------  6.8/6.8 MB 87.6 MB/s eta 0:00:01
#      ---------------------------------------- 6.8/6.8 MB 72.7 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
# ...
